# %%
bank =input("please keep the card:")
name =["vasavi","bindu"]
print("hello", bank,"!welcome to smart360 bank.")
# Out:
# hello SBI !welcome to smart360 bank.

# %%
name = input("enter your name: ")
age  = int(input("enter your age: "))
account_balance = float(input("enter your accontbalance: "))
print("name:", name)
print("age:", age)
print("account balance:", account_balance)
# Out:
# name: vasavi
# age: 20
# account balance: 2000.0

# %%
bank=input("what is your name")
print("name=",bank)
age=input("age:")
print("age:",age)
accountbalance=input("what is your balance")
print("balance",accountbalance)
print("welcome to smart360 bank")
# Out:
# name= bindu
# age: 20
# balance 5000
# welcome to smart360 bank

# %%
bank=input("enter your name")
age=int(input("enter your age"))
accountbalance=int(input("available balance"))
print("welcome to sbi bank",name,"age of customer",age,"available balance",accountbalance)
# Out:
# welcome to sbi bank vasavi age of customer 22 available balance 10000

# %%
saving_acc,salary_acc = input ("enter number of saving_acc and salary_acc: ").split()
print("no.of saving acc:",saving_acc)
print("no.of salary acc:",salary_acc)
# Out:
# no.of saving acc: 46
# no.of salary acc: 10
